# %% [markdown]
# ### Setup

# %%
suppressPackageStartupMessages({
  library(tidyverse)
  library(cowplot)
  library(ggpubr)
  library(grid)
  library(ggplot2)
})

AMP_COL    <- "#6D2682"
GROWTH_COL <- "#2BBFD9"

out_dir <- "../figs"

FS_ALL    <- 26
TEXT_GEOM <- 8.5

pSpacer <- ggplot() +
  theme_void() +
  theme(
    plot.background  = element_rect(fill = "white", colour = NA),
    panel.background = element_rect(fill = "white", colour = NA)
  )

# species labels without HAMBI codes
scale_labels <- c(
  expression(italic('Chitinophaga sancti')),
  expression(italic('Paracoccus denitrificans')),
  expression(italic('Moraxella canis')),
  expression(italic('Microvirga lotononidis')),
  expression(italic('Bordetella avium')),
  expression(italic('Niabella yanshanensis')),
  expression(italic('Hafnia alvei')),
  expression(italic('Morganella morganii')),
  expression(italic('Acinetobacter lwoffii')),
  expression(italic('Sphingobium yanoikuyae')),
  expression(italic('Brevundimonas bullata')),
  expression(italic('Kluyvera intermedia')),
  expression(italic('Cupriavidus oxalaticus')),
  expression(italic('Paraburkholderia kururiensis')),
  expression(italic('Agrobacterium tumefaciens')),
  expression(italic('Stenotrophomonas maltophilia')),
  expression(italic('Citrobacter koseri')),
  expression(italic('Pseudomonas putida')),
  expression(italic('Sphingobacterium spiritivorum')),
  expression(italic('Aeromonas caviae')),
  expression(italic('Comamonas testosteroni')),
  expression(italic('Pseudomonas chlororaphis')),
  expression(italic('Paraburkholderia caryophylli'))
)

# %% [markdown]
# ### Panel A data (MIC + carrying capacity)

# %%
df <- read.table("../data/AMP_growth_k_auc.txt", header = TRUE, check.names = FALSE, sep = "\t")
df$k <- ifelse(df$k < 0.1 | df$k > 1.3, 0, df$k)
df <- df[df$Species != "only medium", ]

df <- df %>%
  mutate(strainID = paste0("HAMBI-", str_pad(Species, 4, pad = "0"))) %>%
  select(strainID, AB, Pop, Replicate, k)

df$Treat <- with(df, paste(strainID, Pop, Replicate, sep = "_"))
Treatments <- unique(df$Treat)

# MIC per clone, stop at two successive zeros
df$MIC <- NA_real_
for (i in seq_along(Treatments)) {
  a <- df[df$Treat == Treatments[i], ]
  a <- a[order(a$AB), ]
  a$nextzero <- "no"
  if (nrow(a) >= 2) {
    for (j in seq_len(nrow(a) - 1)) {
      if (a$k[j] == 0 && a$k[j + 1] == 0) { a$nextzero[j] <- "yes"; break }
    }
  }
  minnextzero <- ifelse(any(a$nextzero == "yes"),
                        suppressWarnings(min(a$AB[a$nextzero == "yes"], na.rm = TRUE)),
                        2050)
  a <- a[a$AB < minnextzero, ]
  a_MIC <- suppressWarnings(max(a$AB[a$k > 0], na.rm = TRUE))
  if (is.infinite(a_MIC)) a_MIC <- 0
  df$MIC[df$Treat == Treatments[i]] <- a_MIC
}

# keep one row per clone + AB==0 k
df2  <- df[!duplicated(df$Treat), c("strainID", "Pop", "Replicate", "Treat", "MIC")]
df_k <- df[df$AB == 0, c("strainID", "Pop", "Replicate", "Treat", "k")]
df3  <- merge(df2, df_k, by = c("strainID", "Pop", "Replicate", "Treat"))

df3$log10MIC <- log10(df3$MIC + 1e-5)

# species order by ancestral MIC
df4 <- aggregate(cbind(log10MIC, k) ~ strainID + Pop, data = df3, FUN = mean, na.rm = TRUE)
speciesord <- df4 %>% dplyr::filter(Pop == "ANC") %>% arrange(log10MIC) %>% pull(strainID)

df3$strainID <- factor(df3$strainID, levels = speciesord)
df3$Pop <- factor(df3$Pop, levels = c("ANC", "EVO"), labels = c("Ancestral", "Primed"))

df7 <- bind_rows(
  df3 %>% transmute(strainID, Pop, Replicate, Trait = log10MIC, Trait_type = "log10MIC"),
  df3 %>% transmute(strainID, Pop, Replicate, Trait = k,       Trait_type = "k")
)

df7$Trait_type <- factor(df7$Trait_type, levels = c("log10MIC", "k"))
df7$Panel <- factor(
  ifelse(df7$Trait_type == "log10MIC", "Log10 MIC", "Carrying capacity"),
  levels = c("Log10 MIC", "Carrying capacity")
)

# remove HAMBI-1988 from plotting
df7A <- df7 %>% filter(strainID != "HAMBI-1988")
speciesord_A <- setdiff(speciesord, "HAMBI-1988")
df7A$strainID <- factor(df7A$strainID, levels = speciesord_A)

# summaries (no x-offset)
df7A_sum <- df7A %>%
  group_by(strainID, Pop, Panel, Trait_type) %>%
  summarise(
    mean = mean(Trait, na.rm = TRUE),
    se   = sd(Trait, na.rm = TRUE) / sqrt(sum(is.finite(Trait))),
    .groups = "drop"
  )

# reference lines + labels
A_LABEL_NUDGE <- 0.070
hlines_df <- tibble(
  Panel = factor("Log10 MIC", levels = levels(df7A$Panel)),
  yint  = log10(c(5, 50, 500)),
  lab   = c("Low", "Intermediate", "High")
)

trait_col <- c("log10MIC" = AMP_COL, "k" = GROWTH_COL)
pop_fill  <- c("Ancestral" = "white", "Primed" = "grey15")
pop_shape <- c("Ancestral" = 21, "Primed" = 24)

pA <- ggplot(df7A, aes(x = strainID, y = Trait)) +
  geom_point(
    aes(shape = Pop, fill = Pop, colour = Trait_type),
    alpha = 0.22, size = 3.6, stroke = 1.4,
    position = position_identity(),
    show.legend = FALSE
  ) +
  geom_errorbar(
    data = df7A_sum,
    aes(x = strainID, y = mean, ymin = mean - se, ymax = mean + se, colour = Trait_type),
    inherit.aes = FALSE,
    width = 0.12, linewidth = 1.3,
    show.legend = FALSE
  ) +
  geom_point(
    data = df7A_sum,
    aes(x = strainID, y = mean, shape = Pop, fill = Pop, colour = Trait_type),
    inherit.aes = FALSE,
    size = 5.2, stroke = 1.8,
    show.legend = FALSE
  ) +
  geom_hline(
    data = hlines_df,
    aes(yintercept = yint),
    colour = AMP_COL, linetype = 2, linewidth = 0.9
  ) +
  geom_text(
    data = hlines_df,
    aes(x = 1, y = yint + A_LABEL_NUDGE, label = lab),
    hjust = 0, vjust = 0, size = TEXT_GEOM,
    colour = "black"
  ) +
  facet_grid(Panel ~ ., scales = "free_y", switch = "y") +
  scale_colour_manual(values = trait_col, guide = "none") +
  scale_fill_manual(values = pop_fill, guide = "none") +
  scale_shape_manual(values = pop_shape, guide = "none") +
  scale_x_discrete(
    labels = scale_labels[-1],
    expand = expansion(add = 0.30)   # slightly more space at left/right
  ) +
  coord_cartesian(clip = "off") +
  labs(x = NULL, y = NULL) +
  theme_classic(base_size = FS_ALL) +
  theme(
    panel.spacing.y   = unit(0.05, "lines"),
    strip.background  = element_blank(),
    strip.placement   = "outside",
    strip.text.y.left = element_text(face = "bold", size = FS_ALL),
    axis.text.x       = element_text(angle = 40, hjust = 1, vjust = 1, size = FS_ALL, colour = "black"),
    axis.text.y       = element_text(size = FS_ALL, colour = "black"),
    axis.title        = element_text(size = FS_ALL, face = "bold", colour = "black"),
    legend.position   = "none",
    # big left margin so long rotated labels never clip
    plot.margin       = margin(6, 6, 4, 245)
  )

# %% [markdown]
# ### Panel B: trait change boxplots (traits scaled 0–1 before Δ)

# %%
trait_means <- df3 %>%
  filter(strainID != "HAMBI-1988") %>%
  group_by(strainID, Pop) %>%
  summarise(
    log10MIC_mean = mean(log10MIC, na.rm = TRUE),
    k_mean        = mean(k,        na.rm = TRUE),
    .groups = "drop"
  )

trait_means_scaled <- trait_means %>%
  mutate(
    MIC_scaled = (log10MIC_mean - min(log10MIC_mean, na.rm = TRUE)) /
      (max(log10MIC_mean, na.rm = TRUE) - min(log10MIC_mean, na.rm = TRUE)),
    k_scaled   = (k_mean - min(k_mean, na.rm = TRUE)) /
      (max(k_mean, na.rm = TRUE) - min(k_mean, na.rm = TRUE))
  )

diff_long <- trait_means_scaled %>%
  select(strainID, Pop, MIC_scaled, k_scaled) %>%
  pivot_longer(cols = c(MIC_scaled, k_scaled), names_to = "Trait_raw", values_to = "Value") %>%
  mutate(Trait = recode(Trait_raw, "MIC_scaled" = "Log10 MIC", "k_scaled" = "Carrying capacity")) %>%
  select(-Trait_raw) %>%
  pivot_wider(names_from = Pop, values_from = Value) %>%
  mutate(Diff = `Primed` - `Ancestral`) %>%
  filter(is.finite(Diff), !is.na(Diff)) %>%
  mutate(Trait = factor(Trait, levels = c("Log10 MIC", "Carrying capacity")))

pB <- ggplot(diff_long, aes(x = Trait, y = Diff, colour = Trait)) +
  geom_hline(yintercept = 0, linetype = 2, colour = "grey40", linewidth = 0.9) +
  geom_boxplot(width = 0.55, linewidth = 1.4, outlier.shape = NA, colour = "black") +
  geom_point(
    position = position_jitter(width = 0.08, height = 0),
    alpha = 0.55, size = 3.2, stroke = 0.9,
    show.legend = FALSE
  ) +
  scale_colour_manual(values = c("Log10 MIC" = AMP_COL, "Carrying capacity" = GROWTH_COL), guide = "none") +
  labs(x = NULL, y = "Trait change (primed − anc)\n(traits scaled 0–1)") +
  theme_bw(base_size = FS_ALL) +
  theme(
    panel.grid       = element_blank(),
    panel.background = element_rect(fill = "white", colour = NA),
    plot.background  = element_rect(fill = "white", colour = NA),
    panel.border     = element_rect(colour = "black", fill = NA, linewidth = 1.2),
    axis.text.x      = element_text(size = FS_ALL, angle = 40, hjust = 1, colour = "black"),
    axis.title.y     = element_text(face = "bold", size = FS_ALL, colour = "black"),
    axis.text.y      = element_text(size = FS_ALL, colour = "black"),
    legend.position  = "none",
    plot.margin      = margin(0, 22, 4, 8)
  )

# %% [markdown]
# ### Panel C: mutation heatmap (remove hypothetical/NA variants) + panel border

# %%
wgs <- read.table("../data/curated_wgs_nonsyn_mutations.txt", header = TRUE, sep = "\t")
sample_order <- c("HAMBI_1972","HAMBI_2160","HAMBI_2659","HAMBI_0105","HAMBI_1977")

variant_order <- rev(c(
  "H1972_00439_ftsI_p.Gly537Val",
  "H1972_01245_erfK_p.Thr229Pro",
  "H1972_03930_rpoA_p.Ala308Pro",
  "H2160_00934_cysS_p.Arg307His",
  "H2659_00656_smf-1_p.Ala9fs",
  "H0105_04901_rbsA_6_p.Val387Glu",
  "H1977_01749_rne_p.Arg518fs",
  "H1977_03891_ampR_p.Asp135Asn"
))

scale_labels2 <- c(
  expression(italic('Aeromonas caviae')),
  expression(italic('Bordetella avium')),
  expression(italic('Stenotrophomonas maltophilia')),
  expression(italic('Agrobacterium tumefaciens')),
  expression(italic('Pseudomonas chlororaphis'))
)

extract_gene <- function(v) {
  v %>% str_replace(".*_[0-9]{5}_", "") %>% str_replace("_p\\..*$", "")
}

heat_long <- wgs %>%
  filter(Variant %in% variant_order) %>%
  transmute(
    Sample  = factor(Sample, levels = sample_order),
    Variant = factor(Variant, levels = variant_order),
    Hit = 1L
  ) %>%
  tidyr::complete(Sample, Variant, fill = list(Hit = 0L)) %>%
  mutate(
    gene = extract_gene(as.character(Variant)),
    Hit  = factor(Hit, levels = c(0,1))
  ) %>%
  filter(!is.na(gene), gene != "", gene != "NA")

pC <- ggplot(heat_long, aes(x = Sample, y = Variant, fill = Hit)) +
  geom_tile(colour = "grey92", linewidth = 0.65) +
  scale_fill_manual(values = c("0" = "white", "1" = AMP_COL), guide = "none") +
  scale_x_discrete(labels = scale_labels2, expand = expansion(add = 0.02)) +
  scale_y_discrete(
    position = "right",
    labels = function(v) parse(text = paste0("italic(", extract_gene(v), ")"))
  ) +
  labs(y = "Gene with nonsynonymous mutation", x = NULL) +
  theme_bw(base_size = FS_ALL) +
  theme(
    panel.grid       = element_blank(),
    panel.background = element_rect(fill = "white", colour = NA),
    plot.background  = element_rect(fill = "white", colour = NA),
    panel.border     = element_rect(colour = "black", fill = NA, linewidth = 1.2),
    axis.text.x      = element_text(angle = 40, hjust = 1, vjust = 1, size = FS_ALL, colour = "black"),
    axis.title.y     = element_text(face = "bold", size = FS_ALL, colour = "black"),
    axis.text.y      = element_text(size = FS_ALL, colour = "black"),
    legend.position  = "none",
    plot.margin      = margin(6, 6, 4, 0)
  )

# %% [markdown]
# ### Panel D: time series (panel borders for each facet) + global legend

# %%
df_key_species <- read.table("../data/AMP_key_species.txt", header = TRUE, sep = "\t", dec = ",")

df4ks <- df_key_species %>%
  filter(Species %in% c("HAMBI_403", "HAMBI_1972", "HAMBI_1977")) %>%
  mutate(
    Evo = factor(Evo, levels = c("ANC", "EVO"), labels = c("Ancestral", "Primed")),
    Species = factor(
      Species,
      levels = c("HAMBI_1972", "HAMBI_403", "HAMBI_1977"),
      labels = c(
        "italic(Aeromonas~caviae)",
        "italic(Comamonas~testosteroni)",
        "italic(Pseudomonas~chlororaphis)"
      )
    ),
    FillEvo = Evo
  )

scaleFactor2 <- max(df4ks$AMP_conc, na.rm = TRUE) / max(df4ks$OD, na.rm = TRUE)
df4ks_long <- df4ks %>% mutate(C_amp = AMP_conc, Biomass = OD)

pD_base <- ggplot(df4ks_long, aes(Timeh, group = Evo)) +
  stat_summary(aes(y = C_amp, colour = "C_amp", linetype = Evo),
               fun = mean, geom = "line", linewidth = 1.1) +
  stat_summary(aes(y = C_amp, colour = "C_amp", shape = Evo, fill = FillEvo),
               fun = mean, geom = "point", size = 5.2, stroke = 1.8) +
  geom_jitter(aes(y = C_amp, colour = "C_amp", shape = Evo, fill = FillEvo),
              position = position_jitter(width = 0.35, height = 0),
              alpha = 0.20, size = 3.6, stroke = 1.4) +
  stat_summary(aes(y = Biomass * scaleFactor2, colour = "Biomass", linetype = Evo),
               fun = mean, geom = "line", linewidth = 1.1) +
  stat_summary(aes(y = Biomass * scaleFactor2, colour = "Biomass", shape = Evo, fill = FillEvo),
               fun = mean, geom = "point", size = 5.2, stroke = 1.8) +
  geom_jitter(aes(y = Biomass * scaleFactor2, colour = "Biomass", shape = Evo, fill = FillEvo),
              position = position_jitter(width = 0.35, height = 0),
              alpha = 0.20, size = 3.6, stroke = 1.4) +
  scale_x_continuous(breaks = c(0, 6, 12, 24)) +
  scale_colour_manual(
    values = c("C_amp" = AMP_COL, "Biomass" = GROWTH_COL),
    breaks = c("C_amp", "Biomass"),
    labels = c(expression(C[amp]), "Biomass"),
    name = NULL
  ) +
  scale_shape_manual(values = c("Ancestral" = 21, "Primed" = 24), name = NULL) +
  scale_fill_manual(values = c("Ancestral" = "white", "Primed" = "grey15"), name = NULL) +
  scale_linetype_manual(values = c("Ancestral" = "solid", "Primed" = "dashed"), name = NULL) +
  scale_y_continuous(name = NULL, sec.axis = sec_axis(~ . / scaleFactor2, name = NULL)) +
  labs(x = "Time (h)") +
  facet_grid(. ~ Species, scales = "free_y", labeller = label_parsed) +
  theme_bw(base_size = FS_ALL) +
  theme(
    panel.grid       = element_blank(),
    panel.background = element_rect(fill = "white", colour = NA),
    plot.background  = element_rect(fill = "white", colour = NA),
    panel.border     = element_rect(colour = "black", fill = NA, linewidth = 1.2),
    axis.title.x     = element_text(face = "bold", size = FS_ALL, colour = "black"),
    axis.text        = element_text(size = FS_ALL, colour = "black"),
    strip.background = element_blank(),
    strip.text       = element_text(size = FS_ALL),
    legend.position  = "top",
    legend.text      = element_text(size = FS_ALL),
    legend.title     = element_blank(),
    plot.margin      = margin(6, 6, 4, 6)
  )

global_legend <- get_legend(pD_base + theme(legend.position = "top"))
pD_noleg <- pD_base + theme(legend.position = "none")

# bold y titles drawn outside plot (avoid gp font errors)
left_title  <- expression(bold(C[amp]~"("*mu*g~mL^-1*")"))
right_title <- expression(bold(Biomass~"("*OD[600]*")"))

pD_drawn <- ggdraw(pD_noleg) +
  draw_label(label = left_title,  x = -0.040, y = 0.52, angle = 90,
             size = FS_ALL, fontface = "bold", hjust = 0.5, vjust = 0.5) +
  draw_label(label = right_title, x = 1.040, y = 0.52, angle = 270,
             size = FS_ALL, fontface = "bold", hjust = 0.5, vjust = 0.5)

pD_padded <- ggdraw() +
  draw_plot(pD_drawn, x = 0.175, y = 0, width = 0.777, height = 1)

# %% [markdown]
# ### Combine (A | B | spacer | C) on top; D on bottom; global legend on top

# %%
top_row_no_tags <- plot_grid(
  pA, pB, pSpacer, pC,
  ncol = 4,
  rel_widths = c(0.62, 0.15, 0.05, 0.18),
  align = "hv",
  axis = "tb"
)

A_LABEL_X <- 0.065
D_LABEL_X <- 0.065
C_LABEL_X <- 0.777   # label slightly right

top_row <- ggdraw(top_row_no_tags) +
  draw_plot_label(
    label = c("A", "B", "C"),
    x     = c(A_LABEL_X, 0.63, C_LABEL_X),
    y     = c(0.995, 0.995, 0.995),
    size  = FS_ALL + 8,
    fontface = "bold"
  )

#bottom_row <- ggdraw(pD_padded) +
#  draw_plot_label(
#    label = "D",
#    x = D_LABEL_X, y = 1.01,
#    size = FS_ALL + 8,
#    fontface = "bold"
#  )

panels <- plot_grid(
  top_row,
#  bottom_row,
  ncol = 1,
  rel_heights = c(0.72, 0.28)
)

final_plot <- plot_grid(
  global_legend,
  panels,
  ncol = 1,
  rel_heights = c(0.07, 0.93)
)

pdf(file.path(out_dir, "Fig2.pdf"), width = 25, height = 12, bg = "white")
print(final_plot)
dev.off()
# Out:
# pdf
#   2

# %% [markdown]
# ## Initial strain MIC and carrying capacity: ANOVA

# %%
# Read in data

df = read.table("../data/AMP_growth_k_auc.txt", header = T, check.names = F, sep = "\t")
#head(df)

# Use medium control data to infer threshold level for no growth

#max(df$k[df$Species == "only medium"])
#mean(df$k[df$Species == "only medium"])

# Inspect mean and max levels in the absence of antibiotics

#aggregate(data = df[df$AB == 0,], k ~ Species, FUN = mean) 
#aggregate(data = df[df$AB == 0,], k ~ Species, FUN = max) 

# Any value above 1.3 seems to result from no growth (low strain growth causing unreliable k estimation)
# Any value below 0.1 seems to be unreliable

# Let's convert these values to 0

df$k = ifelse(df$k < 0.1 | df$k > 1.3, 0, df$k)

# Inspect

#max(df$k)
#min(df$k)

# Remove control measurements

#nrow(df)
df = df[df$Species != "only medium",]
#nrow(df) # ok

# Convert strain numbers to HAMBI codes

df = df %>%
  mutate(strainID = paste0("HAMBI-", str_pad(Species, 4, pad = c("0"))))
df = df[,c("strainID", "AB", "Pop", "Replicate", "k")]
#head(df)

# Add treatment information

df$Treat = paste(df$strainID, df$Pop, df$Replicate, sep = "_")
#head(df)

# Create vector for treatments

Treatments = unique(df$Treat)

# For each unique clone (strainID, ANC/EVO, Replicate) compute MIC as the highest concentration where k > 0,
# omitting positive values after two successive zero counts as errors

df$MIC = NA
for(i in 1:length(Treatments)){
    a = df[df$Treat == Treatments[i],] # extract all AB growth data per clone
    a = a[order(a$AB),] # order rows by increasing AB concentration
    a$nextzero = NA
    for(j in 1:nrow(a)){
        a$nextzero[j] = ifelse(a$k[j] == 0 & a$k[j+1] == 0, "yes", "no")
    } # loop to add information whether next row after k = 0 row is also k = 0 (two successive zero counts)
    # next store information on lowest AB level where two following k values are zero
    # (or if two consecutive zero rows never occur, add high AB value 2050 to enable code to run)
    minnextzero = ifelse(length(a$AB[a$nextzero == "yes"]) == 0, 2050, 
                         suppressWarnings(min(a$AB[a$nextzero == "yes"], na.rm = T)))
    a = a[a$AB<minnextzero,] # remove rows with AB levels above that followed by multiple zero rows
    a_MIC = suppressWarnings(max(a$AB[a$k>0], na.rm = T)) # take as clone MIC highest remaining AB value with non-zero growth
    a_MIC[is.infinite(a_MIC)] <- 0 # convert potential -Inf values to 0
    df$MIC[df$Treat == Treatments[i]] = a_MIC
}
# Remove duplicate rows (for each AB level)
df2 = df[!duplicated(df$Treat),c("strainID", "Pop", "Replicate", "Treat", "MIC")]
#nrow(df2) # 92 correct (23 strains x ANC/EVO x 2 replicates)

# Add k for antibiotic-free condition

df_k = df[df$AB == 0, c("strainID", "Pop", "Replicate", "Treat", "k")]

df3 = merge(df2, df_k, by = c("strainID", "Pop", "Replicate", "Treat"))
#nrow(df3)

# Reorder
df3 = df3[order(df3$strainID, df3$Pop),]
#head(df3)

# Add very small random noise to allow log conversion and statistical testing of 0 values

set.seed(1) 
df3$noise = runif(nrow(df3),1e-5,1e-4)
#head(df3)

df3$log10MIC = log10(df3$MIC + df3$noise) 
df3$MIC_noise = df3$MIC + df3$noise
df3$k_noise = df3$k + df3$noise

#head(df3)

M_MIC = lm(log10MIC ~ strainID*Pop, data = df3)
aov_mic = anova(M_MIC)
rownames(aov_mic) = c("Strain", "Ampicillin pre-exposure", "Strain x ampicillin pre-exposure", "Residuals")
aov_mic = cbind("Factor"=rownames(aov_mic), aov_mic)
aov_mic

# Overall, MIC significantly increases with pre-exposure, although the effect depends on the species

M_k = lm(k ~ strainID*Pop, data = df3)
aov_k = anova(M_k)
rownames(aov_k) = c("Strain", "Ampicillin pre-exposure", "Strain x ampicillin pre-exposure", "Residuals")
aov_k = cbind("Factor"=rownames(aov_k), aov_k)
aov_k

# Overall, k significantly decreases with pre-exposure, although the effect depends on the species

# Check species with highest effect size

df3_effect_anc = aggregate(data = df3[df3$Pop == "ANC",c("strainID", "Replicate", "log10MIC", "k")], cbind(log10MIC, k) ~ strainID, FUN = mean)
colnames(df3_effect_anc) = c("strainID", "log10MIC_ANC", "k_ANC")

df3_effect_evo = aggregate(data = df3[df3$Pop == "EVO",c("strainID", "Replicate", "log10MIC", "k")], cbind(log10MIC, k) ~ strainID, FUN = mean)
colnames(df3_effect_evo) = c("strainID", "log10MIC_EVO", "k_EVO")

df3_effect = merge(df3_effect_anc, df3_effect_evo, by = "strainID")

df3_effect$log10MIC_ratio = df3_effect$log10MIC_EVO	/ df3_effect$log10MIC_ANC
df3_effect$k_ratio = df3_effect$k_EVO	/ df3_effect$k_ANC

head(df3_effect)
# Out:
#                                  Factor                           Df Sum Sq
# Strain                           Strain                           22 401.70863
# Ampicillin pre-exposure          Ampicillin pre-exposure           1  25.21581
# Strain x ampicillin pre-exposure Strain x ampicillin pre-exposure 22  25.72324
# Residuals                        Residuals                        46  25.63558
#                                  Mean Sq    F value   Pr(>F)
# Strain                           18.2594831 32.764474 4.026464e-21
# Ampicillin pre-exposure          25.2158118 45.246780 2.345139e-08
# Strain x ampicillin pre-exposure  1.1692380  2.098059 1.712232e-02
# Residuals                         0.5572952        NA           NA
#                                  Factor                           Df Sum Sq
# Strain                           Strain                           22 3.88141910
# Ampicillin pre-exposure          Ampicillin pre-exposure           1 0.04856283
# Strain x ampicillin pre-exposure Strain x ampicillin pre-exposure 22 1.13724630
# Residuals                        Residuals                        46 0.44950239
#                                  Mean Sq     F value   Pr(>F)
# Strain                           0.176428141 18.054842 7.644499e-16
# Ampicillin pre-exposure          0.048562826  4.969695 3.071970e-02
# Strain x ampicillin pre-exposure 0.051693014  5.290024 9.932510e-07
# Residuals                        0.009771791        NA           NA
#   strainID   log10MIC_ANC k_ANC     log10MIC_EVO k_EVO     log10MIC_ratio
# 1 HAMBI-0006  1.4520724   0.8215607  3.2129844   0.5753560  2.2126888
# 2 HAMBI-0097 -0.1327175   1.1176546 -0.3967974   0.5416475  2.9897888
# 3 HAMBI-0105  0.6596650   0.5974698  0.7477089   0.5340331  1.1334676
# 4 HAMBI-0262  0.1314060   0.2981430  0.7477119   0.2794971  5.6900887
# 5 HAMBI-0403  2.5966651   0.1961860  2.5086194   0.2362334  0.9660928
# 6 HAMBI-1279 -0.3968197   0.1636622  1.8923002   0.2181412 -4.7686646
#   k_ratio
# 1 0.7003208
# 2 0.4846288
# 3 0.8938243
# 4 0.9374599
# 5 1.2041295
# 6 1.3328745

# %% [markdown]
# ### Ampicillin degradation analysis and stats

# %%
# ---- Load and filter ----
dat <- read.table("../data/AMP_key_species.txt", header=TRUE, sep="\t", dec=",") %>%
  filter(Species == "HAMBI_1972") %>%
  mutate(
    Evo   = factor(Evo, levels=c("ANC","EVO"),
                   labels=c("Ancestral","Pre-exposed")),
    Timeh = as.numeric(Timeh),
    AMP_conc = as.numeric(AMP_conc),
    OD = as.numeric(OD)
  )

# ---- Fixed baseline per Evo ----
init_by_evo <- dat %>%
  filter(Timeh == 0) %>%
  group_by(Evo) %>%
  summarise(init = mean(AMP_conc, na.rm=TRUE), .groups="drop")

dat <- dat %>%
  left_join(init_by_evo, by="Evo") %>%
  mutate(AMP_rel = AMP_conc / init)

# ---- Absolute threshold < 10 µg/mL ----
deg_time_abs <- dat %>%
  group_by(Evo, Replicate) %>%
  summarise(Time_to_deg = min(Timeh[AMP_conc < 10], na.rm = TRUE), .groups = "drop") %>%
  mutate(Time_to_deg = ifelse(is.infinite(Time_to_deg), NA, Time_to_deg))

print(deg_time_abs)

# ---- Correct Wilcoxon (Pre-exposed earlier) ----
wilx <- wilcox.test(
  x = deg_time_abs$Time_to_deg[deg_time_abs$Evo == "Pre-exposed"],
  y = deg_time_abs$Time_to_deg[deg_time_abs$Evo == "Ancestral"],
  alternative = "less",   # now correct direction
  exact = TRUE, correct = FALSE
)
wilx

# ---- Fisher’s exact at 6 h (<10 µg/mL) ----
deg6_abs <- dat %>%
  filter(Timeh == 6) %>%
  mutate(Degraded10 = AMP_conc < 10)

tab6 <- table(deg6_abs$Evo, deg6_abs$Degraded10)
print(tab6)
print(fisher.test(tab6, alternative="greater"))

# ---- Welch t-test for OD ----
t_od <- t.test(OD ~ Evo, data = deg6_abs, var.equal = FALSE)
t_od

# ---- Correlation between degradation time and growth ----
summ_merge <- left_join(deg_time_abs,
                        deg6_abs %>% select(Evo, Replicate, OD6 = OD),
                        by=c("Evo","Replicate"))
cor.test(summ_merge$Time_to_deg, summ_merge$OD6, method="spearman")
# Out:
# # A tibble: 6 × 3
#   Evo         Replicate Time_to_deg
#   <fct>           <int>       <dbl>
# 1 Ancestral           1          12
# 2 Ancestral           2          12
# 3 Ancestral           3          12
# 4 Pre-exposed         1           6
# 5 Pre-exposed         2           6
# 6 Pre-exposed         3           6
# Warning message in wilcox.test.default(x = deg_time_abs$Time_to_deg[deg_time_abs$Evo == :
# “cannot compute exact p-value with ties”
# 	Wilcoxon rank sum test
#
# data:  deg_time_abs$Time_to_deg[deg_time_abs$Evo == "Pre-exposed"] and deg_time_abs$Time_to_deg[deg_time_abs$Evo == "Ancestral"]
# W = 0, p-value = 0.01267
# alternative hypothesis: true location shift is less than 0
#
#               FALSE TRUE
#   Ancestral       3    0
#   Pre-exposed     0    3
#
# 	Fisher's Exact Test for Count Data
#
# data:  tab6
# p-value = 0.05
# alternative hypothesis: true odds ratio is greater than 1
# 95 percent confidence interval:
#    1 Inf
# sample estimates:
# odds ratio
#        Inf
# 	Welch Two Sample t-test
#
# data:  OD by Evo
# t = -29.309, df = 2.1514, p-value = 0.0007719
# alternative hypothesis: true difference in means between group Ancestral and group Pre-exposed is not equal to 0
# 95 percent confidence interval:
#  -0.2096488 -0.1590179
# sample estimates:
#   mean in group Ancestral mean in group Pre-exposed
#                0.04233333                0.22666667
# Warning message in cor.test.default(summ_merge$Time_to_deg, summ_merge$OD6, method = "spearman"):
# “Cannot compute exact p-value with ties”
# 	Spearman's rank correlation rho
#
# data:  summ_merge$Time_to_deg and summ_merge$OD6
# S = 65.741, p-value = 0.02131
# alternative hypothesis: true rho is not equal to 0
# sample estimates:
#        rho
# -0.8783101

# %%
# =========================================================
# Degradation stats for the other two strains
# =========================================================

other_strains <- c("HAMBI_403", "HAMBI_1977")

for (sp in other_strains) {
  
  cat("\n============================================\n")
  cat("Strain:", sp, "\n")
  cat("============================================\n")
  
  dat_sp <- read.table("../data/AMP_key_species.txt", header=TRUE, sep="\t", dec=",") %>%
    filter(Species == sp) %>%
    mutate(
      Evo   = factor(Evo, levels = c("ANC", "EVO"),
                     labels = c("Ancestral", "Pre-exposed")),
      Timeh = as.numeric(Timeh),
      AMP_conc = as.numeric(AMP_conc),
      OD = as.numeric(OD)
    )
  
  # time to reach <10 ug/mL
  deg_time_abs_sp <- dat_sp %>%
    group_by(Evo, Replicate) %>%
    summarise(
      Time_to_deg = min(Timeh[AMP_conc < 10], na.rm = TRUE),
      .groups = "drop"
    ) %>%
    mutate(Time_to_deg = ifelse(is.infinite(Time_to_deg), NA, Time_to_deg))
  
  cat("\nTime to AMP < 10 ug/mL by replicate:\n")
  print(deg_time_abs_sp)
  
  # Wilcoxon only if both groups have at least one non-NA value
  x_pre <- deg_time_abs_sp$Time_to_deg[deg_time_abs_sp$Evo == "Pre-exposed"]
  y_anc <- deg_time_abs_sp$Time_to_deg[deg_time_abs_sp$Evo == "Ancestral"]
  
  x_pre <- x_pre[!is.na(x_pre)]
  y_anc <- y_anc[!is.na(y_anc)]
  
  cat("\nWilcoxon test for earlier degradation in pre-exposed:\n")
  if (length(x_pre) > 0 & length(y_anc) > 0) {
    print(wilcox.test(
      x = x_pre,
      y = y_anc,
      alternative = "less",
      exact = TRUE,
      correct = FALSE
    ))
  } else {
    cat("Not run: one or both groups never reached <10 ug/mL.\n")
  }
  
  # degradation status at 6 h
  deg6_abs_sp <- dat_sp %>%
    filter(Timeh == 6) %>%
    mutate(Degraded10 = AMP_conc < 10)
  
  cat("\nCounts at 6 h (<10 ug/mL):\n")
  tab6_sp <- table(deg6_abs_sp$Evo, deg6_abs_sp$Degraded10)
  print(tab6_sp)
  
  cat("\nFisher's exact test at 6 h (pre-exposed more often <10 ug/mL):\n")
  if (all(dim(tab6_sp) == c(2, 2))) {
    print(fisher.test(tab6_sp, alternative = "greater"))
  } else {
    cat("Not run: contingency table is not 2 x 2.\n")
  }
  
  # OD comparison at 6 h
  cat("\nWelch t-test for OD at 6 h:\n")
  if (nrow(deg6_abs_sp) > 0 && length(unique(deg6_abs_sp$Evo)) == 2) {
    print(t.test(OD ~ Evo, data = deg6_abs_sp, var.equal = FALSE))
  } else {
    cat("Not run: insufficient 6 h data.\n")
  }
  
  # correlation between time to degradation and OD at 6 h
  summ_merge_sp <- left_join(
    deg_time_abs_sp,
    deg6_abs_sp %>% select(Evo, Replicate, OD6 = OD),
    by = c("Evo", "Replicate")
  )
  
  cat("\nSpearman correlation: degradation time vs OD at 6 h:\n")
  ok <- complete.cases(summ_merge_sp[, c("Time_to_deg", "OD6")])
  if (sum(ok) >= 3) {
    print(cor.test(
      summ_merge_sp$Time_to_deg[ok],
      summ_merge_sp$OD6[ok],
      method = "spearman"
    ))
  } else {
    cat("Not run: too few complete observations.\n")
  }
}
# Out:
# ============================================
# Strain: HAMBI_403
# ============================================
#
# Time to AMP < 10 ug/mL by replicate:
# # A tibble: 6 × 3
#   Evo         Replicate Time_to_deg
#   <fct>           <int>       <dbl>
# 1 Ancestral           1           6
# 2 Ancestral           2           6
# 3 Ancestral           3           6
# 4 Pre-exposed         1           6
# 5 Pre-exposed         2           6
# 6 Pre-exposed         3           6
#
# Wilcoxon test for earlier degradation in pre-exposed:
# Warning message in wilcox.test.default(x = x_pre, y = y_anc, alternative = "less", :
# “cannot compute exact p-value with ties”
# 	Wilcoxon rank sum test
#
# data:  x_pre and y_anc
# W = 4.5, p-value = NA
# alternative hypothesis: true location shift is less than 0
#
#
# Counts at 6 h (<10 ug/mL):
#
#               TRUE
#   Ancestral      3
#   Pre-exposed    3
#
# Fisher's exact test at 6 h (pre-exposed more often <10 ug/mL):
# Not run: contingency table is not 2 x 2.
#
# Welch t-test for OD at 6 h:
#
# 	Welch Two Sample t-test
#
# data:  OD by Evo
# t = 1.6742, df = 3.0966, p-value = 0.1898
# alternative hypothesis: true difference in means between group Ancestral and group Pre-exposed is not equal to 0
# 95 percent confidence interval:
#  -0.01388462  0.04588462
# sample estimates:
#   mean in group Ancestral mean in group Pre-exposed
#                     0.073                     0.057
#
#
# Spearman correlation: degradation time vs OD at 6 h:
# Warning message in cor(rank(x), rank(y)):
# “the standard deviation is zero”
# 	Spearman's rank correlation rho
#
# data:  summ_merge_sp$Time_to_deg[ok] and summ_merge_sp$OD6[ok]
# S = NA, p-value = NA
# alternative hypothesis: true rho is not equal to 0
# sample estimates:
# rho
#  NA
#
#
# ============================================
# Strain: HAMBI_1977
# ============================================
#
# Time to AMP < 10 ug/mL by replicate:
# # A tibble: 6 × 3
#   Evo         Replicate Time_to_deg
#   <fct>           <int>       <dbl>
# 1 Ancestral           1          24
# 2 Ancestral           2          24
# 3 Ancestral           3          24
# 4 Pre-exposed         1          24
# 5 Pre-exposed         2          24
# 6 Pre-exposed         3          24
#
# Wilcoxon test for earlier degradation in pre-exposed:
# Warning message in wilcox.test.default(x = x_pre, y = y_anc, alternative = "less", :
# “cannot compute exact p-value with ties”
# 	Wilcoxon rank sum test
#
# data:  x_pre and y_anc
# W = 4.5, p-value = NA
# alternative hypothesis: true location shift is less than 0
#
#
# Counts at 6 h (<10 ug/mL):
#
#               FALSE
#   Ancestral       3
#   Pre-exposed     3
#
# Fisher's exact test at 6 h (pre-exposed more often <10 ug/mL):
# Not run: contingency table is not 2 x 2.
#
# Welch t-test for OD at 6 h:
#
# 	Welch Two Sample t-test
#
# data:  OD by Evo
# t = 4.726, df = 2.053, p-value = 0.03989
# alternative hypothesis: true difference in means between group Ancestral and group Pre-exposed is not equal to 0
# 95 percent confidence interval:
#  0.005549377 0.093783956
# sample estimates:
#   mean in group Ancestral mean in group Pre-exposed
#                0.10700000                0.05733333
#
#
# Spearman correlation: degradation time vs OD at 6 h:
# Warning message in cor(rank(x), rank(y)):
# “the standard deviation is zero”
# 	Spearman's rank correlation rho
#
# data:  summ_merge_sp$Time_to_deg[ok] and summ_merge_sp$OD6[ok]
# S = NA, p-value = NA
# alternative hypothesis: true rho is not equal to 0
# sample estimates:
# rho
#  NA

# %%
# =========================================================
# Very compact manuscript-oriented summary
# =========================================================

compact_summary <- function(sp) {
  dat_sp <- read.table("../data/AMP_key_species.txt", header=TRUE, sep="\t", dec=",") %>%
    filter(Species == sp) %>%
    mutate(
      Evo   = factor(Evo, levels = c("ANC", "EVO"),
                     labels = c("Ancestral", "Pre-exposed")),
      Timeh = as.numeric(Timeh),
      AMP_conc = as.numeric(AMP_conc),
      OD = as.numeric(OD)
    )
  
  deg_time <- dat_sp %>%
    group_by(Evo, Replicate) %>%
    summarise(Time_to_deg = min(Timeh[AMP_conc < 10], na.rm = TRUE), .groups = "drop") %>%
    mutate(Time_to_deg = ifelse(is.infinite(Time_to_deg), NA, Time_to_deg))
  
  deg6 <- dat_sp %>%
    filter(Timeh == 6) %>%
    mutate(Degraded10 = AMP_conc < 10)
  
  anc_med <- median(deg_time$Time_to_deg[deg_time$Evo == "Ancestral"], na.rm = TRUE)
  pre_med <- median(deg_time$Time_to_deg[deg_time$Evo == "Pre-exposed"], na.rm = TRUE)
  
  anc_deg6 <- sum(deg6$Degraded10[deg6$Evo == "Ancestral"], na.rm = TRUE)
  anc_n6   <- sum(deg6$Evo == "Ancestral")
  pre_deg6 <- sum(deg6$Degraded10[deg6$Evo == "Pre-exposed"], na.rm = TRUE)
  pre_n6   <- sum(deg6$Evo == "Pre-exposed")
  
  cat("\n", sp, ":\n", sep = "")
  cat("median time to <10 ug/mL  | ancestral =", anc_med,
      ", pre-exposed =", pre_med, "\n")
  cat("6 h degraded (<10 ug/mL)  | ancestral =", anc_deg6, "/", anc_n6,
      ", pre-exposed =", pre_deg6, "/", pre_n6, "\n")
}

compact_summary("HAMBI_403")
compact_summary("HAMBI_1977")
# Out:
# HAMBI_403:
# median time to <10 ug/mL  | ancestral = 6 , pre-exposed = 6
# 6 h degraded (<10 ug/mL)  | ancestral = 3 / 3 , pre-exposed = 3 / 3
#
# HAMBI_1977:
# median time to <10 ug/mL  | ancestral = 24 , pre-exposed = 24
# 6 h degraded (<10 ug/mL)  | ancestral = 0 / 3 , pre-exposed = 0 / 3

# %%
# =========================================================
# Minimal addition: MIC-k correlations and simple count summary
# =========================================================

# species means by population
trait_species <- df3 %>%
  group_by(strainID, Pop) %>%
  summarise(
    log10MIC_mean = mean(log10MIC, na.rm = TRUE),
    k_mean        = mean(k, na.rm = TRUE),
    .groups = "drop"
  )

trait_anc <- trait_species %>% filter(Pop == "ANC")
trait_evo <- trait_species %>% filter(Pop == "EVO")

# 1) MIC-k correlation within ancestral species
cat("\n============================================\n")
cat("MIC-k correlation across species: ancestral\n")
cat("============================================\n")
cor_anc <- cor.test(trait_anc$log10MIC_mean, trait_anc$k_mean, method = "spearman", exact = FALSE)
print(cor_anc)

# 2) MIC-k correlation within pre-exposed species
cat("\n============================================\n")
cat("MIC-k correlation across species: pre-exposed\n")
cat("============================================\n")
cor_evo <- cor.test(trait_evo$log10MIC_mean, trait_evo$k_mean, method = "spearman", exact = FALSE)
print(cor_evo)

# 3) correlation between evolutionary changes in MIC and k
trait_change <- trait_species %>%
  pivot_wider(names_from = Pop, values_from = c(log10MIC_mean, k_mean)) %>%
  mutate(
    dMIC = log10MIC_mean_EVO - log10MIC_mean_ANC,
    dk   = k_mean_EVO - k_mean_ANC
  )

cat("\n============================================\n")
cat("Correlation between change in MIC and change in k\n")
cat("============================================\n")
cor_change <- cor.test(trait_change$dMIC, trait_change$dk, method = "spearman", exact = FALSE)
print(cor_change)

# 4) simple counts for manuscript text
trait_change <- trait_change %>%
  mutate(
    MIC_increased = dMIC > 0,
    k_decreased   = dk < 0,
    cost_without_resistance_gain = (dk < 0 & dMIC <= 0)
  )

cat("\n============================================\n")
cat("Simple species counts\n")
cat("============================================\n")
cat("Species with increased MIC:", sum(trait_change$MIC_increased, na.rm = TRUE), "/", nrow(trait_change), "\n")
cat("Species with decreased k:", sum(trait_change$k_decreased, na.rm = TRUE), "/", nrow(trait_change), "\n")
cat("Species with cost without resistance gain:", sum(trait_change$cost_without_resistance_gain, na.rm = TRUE), "/", nrow(trait_change), "\n")

cat("\nSpecies with cost without resistance gain:\n")
print(trait_change %>%
  filter(cost_without_resistance_gain) %>%
  select(strainID, dMIC, dk) %>%
  arrange(dk))

# optional: compact table for supplement
cat("\n============================================\n")
cat("Per-species evolutionary change table\n")
cat("============================================\n")
print(trait_change %>%
  select(strainID, log10MIC_mean_ANC, log10MIC_mean_EVO, dMIC,
         k_mean_ANC, k_mean_EVO, dk) %>%
  arrange(desc(dMIC)))

# species with both increased MIC and decreased k
both_tradeoff <- sum(trait_change$MIC_increased & trait_change$k_decreased, na.rm = TRUE)

cat("Species with increased MIC and decreased k:", both_tradeoff, "/", nrow(trait_change), "\n")

cat("\nSpecies with both increased MIC and decreased k:\n")
print(trait_change %>%
  filter(MIC_increased & k_decreased) %>%
  select(strainID, dMIC, dk) %>%
  arrange(dk))

# =========================================================
# Partition species responses
# =========================================================

both_tradeoff <- sum(trait_change$MIC_increased & trait_change$k_decreased, na.rm = TRUE)
res_only      <- sum(trait_change$MIC_increased & !trait_change$k_decreased, na.rm = TRUE)
cost_only     <- sum(!trait_change$MIC_increased & trait_change$k_decreased, na.rm = TRUE)

cat("\n============================================\n")
cat("Partition of species responses\n")
cat("============================================\n")
cat("Increased MIC + decreased k (trade-off):", both_tradeoff, "/", nrow(trait_change), "\n")
cat("Increased MIC without cost:", res_only, "/", nrow(trait_change), "\n")
cat("Cost without increased MIC:", cost_only, "/", nrow(trait_change), "\n")

# optional: list species in each category
cat("\nSpecies with increased MIC without cost:\n")
print(trait_change %>%
  filter(MIC_increased & !k_decreased) %>%
  select(strainID, dMIC, dk))

cat("\nSpecies with cost without increased MIC:\n")
print(trait_change %>%
  filter(!MIC_increased & k_decreased) %>%
  select(strainID, dMIC, dk))
# Out:
# ============================================
# MIC-k correlation across species: ancestral
# ============================================
#
# 	Spearman's rank correlation rho
#
# data:  trait_anc$log10MIC_mean and trait_anc$k_mean
# S = 1808, p-value = 0.6279
# alternative hypothesis: true rho is not equal to 0
# sample estimates:
#       rho
# 0.1067194
#
#
# ============================================
# MIC-k correlation across species: pre-exposed
# ============================================
#
# 	Spearman's rank correlation rho
#
# data:  trait_evo$log10MIC_mean and trait_evo$k_mean
# S = 1744, p-value = 0.529
# alternative hypothesis: true rho is not equal to 0
# sample estimates:
#       rho
# 0.1383399
#
#
# ============================================
# Correlation between change in MIC and change in k
# ============================================
#
# 	Spearman's rank correlation rho
#
# data:  trait_change$dMIC and trait_change$dk
# S = 1660, p-value = 0.4116
# alternative hypothesis: true rho is not equal to 0
# sample estimates:
#       rho
# 0.1798419
#
#
# ============================================
# Simple species counts
# ============================================
# Species with increased MIC: 19 / 23
# Species with decreased k: 15 / 23
# Species with cost without resistance gain: 3 / 23
#
# Species with cost without resistance gain:
# # A tibble: 3 × 3
#   strainID      dMIC      dk
#   <chr>        <dbl>   <dbl>
# 1 HAMBI-0097 -0.264  -0.576
# 2 HAMBI-3237 -0.0911 -0.473
# 3 HAMBI-1292 -0.176  -0.0111
#
# ============================================
# Per-species evolutionary change table
# ============================================
# # A tibble: 23 × 7
#    strainID   log10MIC_mean_ANC log10MIC_mean_EVO  dMIC k_mean_ANC k_mean_EVO
#    <chr>                  <dbl>             <dbl> <dbl>      <dbl>      <dbl>
#  1 HAMBI-2792            -4.22             -0.221  4.00      0.927     0.634
#  2 HAMBI-3031            -2.38              0.131  2.52      0.310     0.187
#  3 HAMBI-1279            -0.397             1.89   2.29      0.164     0.218
#  4 HAMBI-2443            -4.40             -2.32   2.08      0.659     0.626
#  5 HAMBI-1988            -4.40             -2.56   1.84      0         0.332
#  6 HAMBI-0006             1.45              3.21   1.76      0.822     0.575
#  7 HAMBI-1299             0.307             2.07   1.76      0.405     0.841
#  8 HAMBI-1896             1.54              2.95   1.41      0.285     0.353
#  9 HAMBI-2494             0.484             1.89   1.41      0.620     0.537
# 10 HAMBI-2160            -0.573             0.660  1.23      0.155     0.0582
# # ℹ 13 more rows
# # ℹ 1 more variable: dk <dbl>
# Species with increased MIC and decreased k: 12 / 23
#
# Species with both increased MIC and decreased k:
# # A tibble: 12 × 3
#    strainID         dMIC      dk
#    <chr>           <dbl>   <dbl>
#  1 HAMBI-2792 4.00       -0.293
#  2 HAMBI-0006 1.76       -0.246
#  3 HAMBI-2659 0.00000107 -0.125
#  4 HAMBI-1977 0.528      -0.124
#  5 HAMBI-3031 2.52       -0.123
#  6 HAMBI-2159 0.0880     -0.101
#  7 HAMBI-2160 1.23       -0.0970
#  8 HAMBI-2494 1.41       -0.0834
#  9 HAMBI-0105 0.0880     -0.0634
# 10 HAMBI-1287 0.969      -0.0586
# 11 HAMBI-2443 2.08       -0.0326
# 12 HAMBI-0262 0.616      -0.0186
#
# ============================================
# Partition of species responses
# ============================================
# Increased MIC + decreased k (trade-off): 12 / 23
# Increased MIC without cost: 7 / 23
# Cost without increased MIC: 3 / 23
#
# Species with increased MIC without cost:
# # A tibble: 7 × 3
#   strainID         dMIC     dk
#   <chr>           <dbl>  <dbl>
# 1 HAMBI-1279 2.29       0.0545
# 2 HAMBI-1299 1.76       0.436
# 3 HAMBI-1842 0.00000504 0.285
# 4 HAMBI-1896 1.41       0.0677
# 5 HAMBI-1972 1.06       0.0611
# 6 HAMBI-1988 1.84       0.332
# 7 HAMBI-2164 1.06       0.0925
#
# Species with cost without increased MIC:
# # A tibble: 3 × 3
#   strainID      dMIC      dk
#   <chr>        <dbl>   <dbl>
# 1 HAMBI-0097 -0.264  -0.576
# 2 HAMBI-1292 -0.176  -0.0111
# 3 HAMBI-3237 -0.0911 -0.473
